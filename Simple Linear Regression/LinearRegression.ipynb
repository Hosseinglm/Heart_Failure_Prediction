# %% [markdown]
# Import Libraries

# %% [markdown]
# A line can be represented by the equation: y = m * x + c, where y is the dependent variable, and x is the independent variable. To find the values of m and c using the given dataset, the principles of basic (general) mathematical calculations are used.
#
# Linear regression has 2 types, which are:
# Simple linear regression that uses only one independent variable.
# Multiple linear regression for which different independent variables are defined.

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("Salary_Data.csv")
X = data.drop('Salary', axis=1)
y = data['Salary']

# %% [markdown]
# Split the Dataset to Test and Train

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# %%
y_pred = regressor.predict(X_test)

# %%
Residual = y_pred - y_test
pd.DataFrame({'Actuall Salary ':y_test, 'Salary Predicted': y_pred, 'Residual':Residual}).head(5)
# Out:
#     Actuall Salary   Salary Predicted     Residual
# 20          91738.0      91100.582558  -637.417442
# 24         109431.0     109297.208882  -133.791118
# 7           54445.0      56622.764259  2177.764259
# 18          81363.0      82481.127983  1118.127983
# 2           37731.0      40341.572284  2610.572284

# %%
# Visualize the training set result
plt.scatter(X_train, y_train, color='red')
plt.plot(X_train, regressor.predict(X_train))
plt.title('Salary vs Experience (Train set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')

plt.show()

# %%
#Visualize the test set resualt

plt.scatter(X_test, y_test, color='red')
plt.plot(X_train, regressor.predict(X_train), color='blue')
plt.title('Salary vs Experience (Test set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.show()
